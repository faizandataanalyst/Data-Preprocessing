# %% [markdown]
# ## Import Libraries

# %%
pip install pandas numpy matplotlib seaborn plotly category_encoders scipy
# Out:
# Requirement already satisfied: pandas in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (1.26.2)
# Requirement already satisfied: matplotlib in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (3.8.2)
# Requirement already satisfied: seaborn in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (0.13.1)
# Requirement already satisfied: plotly in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (5.18.0)
# Requirement already satisfied: category_encoders in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (2.6.3)
# Requirement already satisfied: scipy in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (0.5.5)
# Requirement already satisfied: six in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\osman\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as ex
from scipy import stats
import category_encoders as ce

# %% [markdown]
# ## Import Datasets

# %%
# Import Dataset
p1 = pd.read_csv(r"C:\Users\osman\Desktop\Learnings\Excel Data\Salary_Data (Autosaved).csv")
p1
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's                    NaN
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0     NaN                PhD                    NaN
# 3     36.0     NaN         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6698  49.0  Female                PhD  Director of Marketing
# 6699  32.0    Male        High School        Sales Associate
# 6700  30.0  Female  Bachelor's Degree      Financial Manager
# 6701  46.0    Male    Master's Degree      Marketing Manager
# 6702  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0       NaN
# 1                     3.0   65000.0
# 2                     NaN  150000.0
# 3                     7.0   60000.0
# 4                     8.0  200000.0
# ...                   ...       ...
# 6698                 20.0  200000.0
# 6699                  3.0   50000.0
# 6700                  4.0   55000.0
# 6701                 14.0  140000.0
# 6702                  1.0   35000.0
#
# [6703 rows x 6 columns]

# %% [markdown]
# ## Assesing Data (EDA)

# %%
p1.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6700.000000          6699.000000    6697.000000
# mean     33.620597             8.090834  115296.421831
# std       7.615514             6.054840   52811.311911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6703 entries, 0 to 6702
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6700 non-null   float64
#  1   Gender               6700 non-null   object
#  2   Education Level      6700 non-null   object
#  3   Job Title            6700 non-null   object
#  4   Years of Experience  6699 non-null   float64
#  5   Salary               6697 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.3+ KB

# %%
p1.head()
# Out:
#     Age  Gender Education Level        Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's              NaN                  5.0
# 1  28.0  Female        Master's     Data Analyst                  3.0
# 2  45.0     NaN             PhD              NaN                  NaN
# 3  36.0     NaN      Bachelor's  Sales Associate                  7.0
# 4  52.0    Male        Master's         Director                  8.0
#
#      Salary
# 0       NaN
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
p1.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6698  49.0  Female                PhD  Director of Marketing
# 6699  32.0    Male        High School        Sales Associate
# 6700  30.0  Female  Bachelor's Degree      Financial Manager
# 6701  46.0    Male    Master's Degree      Marketing Manager
# 6702  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6698                 20.0  200000.0
# 6699                  3.0   50000.0
# 6700                  4.0   55000.0
# 6701                 14.0  140000.0
# 6702                  1.0   35000.0

# %%
p1.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
p1.nunique()
# Out:
# Age                     41
# Gender                   3
# Education Level          7
# Job Title              193
# Years of Experience     37
# Salary                 446
# dtype: int64

# %%
p1["Age"].unique()
# Out:
# array([32., 28., 45., 36., 52., 29., 42., nan, 26., 48., 35., 40., 27.,
#        44., 33., 39., 25., 51., 34., 47., 30., 41., 37., 24., 43., 50.,
#        31., 46., 49., 38., 23., 53., 61., 57., 62., 55., 56., 54., 60.,
#        58., 22., 21.])

# %%
p1["Salary"].unique()
# Out:
# array([    nan,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000., 140000.,  40000.,  23000.,  90000.,
#         35000., 190000.,  50000.,  30000., 250000.,  75000., 170000.,
#        115000., 160000., 130000., 180000.,  85000.,  95000., 105000.,
#         70000., 100000., 135000., 220000., 175000., 185000., 145000.,
#        155000.,    350., 125000., 195000., 198000., 196000., 193000.,
#         92000., 165000., 162000., 197000., 142000., 182000., 210000.,
#           550., 122485., 169159., 187081., 166109.,  78354.,  90249.,
#        132720., 161568., 127346., 120177.,  69032., 101332., 121450.,
#        166375., 185119., 149217., 166512., 186963.,  75072., 163398.,
#        103947., 179180., 175966., 190004., 152039.,  76742., 191790.,
#        139398.,  95845., 160976., 126753., 161393., 139817., 181714.,
#        114776., 105725.,  52731., 106492.,  73895., 119836.,  99747.,
#        168287., 115920., 128078.,  51265., 165919., 188651.,  55538.,
#        193964., 104702., 172955., 138032.,  82683., 155414., 154207.,
#        107895., 148446., 102859., 138662., 181699., 188232.,  51832.,
#        188484., 138286., 181132.,  73938., 119224., 101186., 142360.,
#        151315., 181021., 134641., 173851., 104127., 178859.,  98568.,
#        104661., 134858.,  94502.,  62852., 139095., 106278.,  90452.,
#        168304., 126593., 152203., 183138., 130275., 191915.,  62807.,
#        174305., 133326.,  75656., 155944., 137775.,  51831., 182237.,
#        151901., 100052., 158254., 167207., 112439., 194214.,  84407.,
#        139413., 143084., 192344., 106132., 184816., 150248., 170995.,
#         88035., 119419., 173582., 174436.,  71699., 163558., 166828.,
#        144496., 193746., 122581.,  79767., 177177.,  89843., 113563.,
#        128712., 161621., 121454., 179987.,  72649.,  52612., 184006.,
#        131960., 102465., 149748., 171036., 146351., 185462., 107718.,
#         90944., 100425.,  63901., 181902., 136533., 136285., 191818.,
#        176643.,  70022.,  99363., 152944., 123386., 168906., 183020.,
#         47898., 135853., 149198., 106662., 186610.,  89995.,  85825.,
#        143814., 174726., 150534.,  68732., 187951., 137336., 191159.,
#        102868., 154281., 111535., 107906., 143885., 180958., 108607.,
#        178284.,  75969., 143705., 197354., 174324., 123781., 141735.,
#        187120.,  61095., 179045., 130355., 103282., 157872., 117314.,
#        186321., 129686.,  68611., 177913.,  68472., 113065., 125091.,
#        172925., 126916., 183417.,  76898.,    579., 103579., 163780.,
#        137878.,  92438.,  84181., 174821., 126520., 152168., 190543.,
#        131547., 192292.,  52807., 174938., 124071.,  73640., 156486.,
#        138859.,  52831., 182392., 151078., 100679., 158966., 167924.,
#        113334., 194778.,  77606., 140010., 142421., 192756., 106686.,
#        186794., 150729., 171652.,  88552., 119918., 174985., 174336.,
#         72389., 163978., 166958., 145052., 195270., 122970.,  80247.,
#        177862.,  91062., 114290., 128999., 162454., 122354., 179756.,
#         73218., 184480., 132442., 102828., 150301., 171468., 147326.,
#        185982., 108267.,  91397., 100867.,  64182., 182506., 136986.,
#        136662., 191510., 177347.,  70397., 146075., 155795., 132638.,
#        178684., 106218., 191239.,  65840.,  52779., 185038., 136449.,
#        110707., 151670., 167015., 146508., 190596., 104378.,  70216.,
#        101733.,  55935., 180367., 135596., 136062., 191267.,  82944.,
#        188288., 141090., 152726., 124141.,  67556., 182768., 148727.,
#         91903., 147708., 163209., 120288., 170226., 134979., 137489.,
#         83577., 117904., 134482., 184660., 100151.,  88678., 181285.,
#        154990., 108204., 175684.,  77766., 192211., 144647., 162231.,
#        121120.,  79652., 177002.,  87584., 131860., 182013., 108799.,
#        135378., 183530., 150901.,  82697., 194638., 130356., 152560.,
#        121432.,  63789., 183690., 151310., 100358., 148437., 168691.,
#        154800.,  32000.,  38000.,  89000.,  33000.,  25000.,  62000.,
#        138000.,  47000.,  26000., 174000.,  41000.,  99000., 117000.,
#        225000.,  36000., 146000., 113000., 168000., 122000.,  96000.,
#         49000.,  68000., 127000.,  71000., 240000., 152000., 119000.,
#        131000., 101000., 137000., 112000.,  91000., 179000.,  74000.,
#        228000.,  37000., 204000.,  61000., 157000.,  52000.,  58000.,
#        219000.,  77000., 104000., 183000.,  43000.,  48000.,  42000.,
#           500.,  57000.,  72000.,  31000.,  28000., 215000.])

# %%
p1["Years of Experience"].unique()
# Out:
# array([ 5. ,  3. ,  nan,  7. ,  8. , 12. ,  4. ,  1. , 10. , 18. ,  6. ,
#        14. , 16. ,  0. ,  2. ,  9. , 13. , 11. , 15. , 25. , 20. , 21. ,
#        22. , 19. , 17. , 23. , 24. ,  0.5,  1.5, 31. , 30. , 28. , 33. ,
#        27. , 34. , 29. , 26. , 32. ])

# %%
sns.histplot(p1, x=p1["Age"],kde=1)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
stats.shapiro(p1["Age"])
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
sns.boxplot(p1["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.histplot(p1, x=p1["Years of Experience"],kde=1)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Count'>

# %%
stats.shapiro(p1["Years of Experience"])
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
sns.boxplot(p1["Years of Experience"])
# Out:
# <Axes: ylabel='Years of Experience'>

# %%
sns.histplot(p1, x=p1["Salary"],kde=1)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
stats.shapiro(p1["Salary"])
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
sns.boxplot(p1["Salary"])
# Out:
# <Axes: ylabel='Salary'>

# %%
sns.barplot(data=p1, x="Age", y="Salary")
plt.show()

# %%
sns.barplot(data=p1, x="Years of Experience", y="Salary")
plt.show()

# %% [markdown]
# ## Cleaning Data

# %%
p1.isnull().sum() / len(p1) * 100
# Out:
# Age                    0.044756
# Gender                 0.044756
# Education Level        0.044756
# Job Title              0.044756
# Years of Experience    0.059675
# Salary                 0.089512
# dtype: float64

# %%
# Imputation
p1["Age"] = p1["Age"].fillna(value=p1['Age'].mean())
p1["Gender"] = p1["Gender"].fillna(value=p1['Gender'].mode()[0])
p1["Education Level"] = p1["Education Level"].fillna(value=p1['Education Level'].mode()[0])
p1["Years of Experience"] = p1["Years of Experience"].fillna(value=p1['Years of Experience'].mean())
p1["Job Title"] = p1["Job Title"].fillna(value=p1['Job Title'].mode()[0])
p1["Salary"] = p1["Salary"].fillna(value=p1['Salary'].mean())

# %%
p1.isnull().sum() / len(p1) * 100
# Out:
# Age                    0.0
# Gender                 0.0
# Education Level        0.0
# Job Title              0.0
# Years of Experience    0.0
# Salary                 0.0
# dtype: float64

# %%
# Ouliers removal
sns.boxplot(p1["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
Q1 = p1["Age"].quantile(0.25) 
Q3 = p1["Age"].quantile(0.75) 
IQR = Q3 - Q1
IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
p1= p1[(p1["Age"] > lower_bound) & (p1["Age"] < upper_bound)] ## Means that the data which have to be taken is is between max and min line

# %%
sns.boxplot(p1["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(p1["Years of Experience"])
# Out:
# <Axes: ylabel='Years of Experience'>

# %%
Q1 = p1["Years of Experience"].quantile(0.25) 
Q3 = p1["Years of Experience"].quantile(0.75) 
IQR = Q3 - Q1
IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
p1= p1[(p1["Years of Experience"] > lower_bound) & (p1["Years of Experience"] < upper_bound)] ## Means that the data which have to be taken is is between max and min line

# %%
sns.boxplot(p1["Salary"])
# Out:
# <Axes: ylabel='Salary'>

# %%
sns.histplot(p1["Age"],kde=1)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(p1["Salary"],kde=1)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(p1["Years of Experience"],kde=1)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Count'>

# %%
p1.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
p1_duplicates = p1[p1.duplicated()]
p1_duplicates.head()
# Out:
#       Age  Gender Education Level                              Job Title  \
# 195  28.0    Male      Bachelor's                Junior Business Analyst
# 250  30.0  Female      Bachelor's           Junior Marketing Coordinator
# 251  38.0    Male        Master's                   Senior IT Consultant
# 252  45.0  Female             PhD                Senior Product Designer
# 253  28.0    Male      Bachelor's  Junior Business Development Associate
#
#      Years of Experience    Salary
# 195                  2.0   40000.0
# 250                  2.0   40000.0
# 251                  9.0  110000.0
# 252                 15.0  150000.0
# 253                  2.0   40000.0

# %%
p1_duplicates.shape
# Out:
# (4823, 6)

# %%
# Duplicates would not be removed because majority duplicates are real values.

# %%
p1.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer             5.000000
# 1  28.0  Female        Master's       Data Analyst             3.000000
# 2  45.0    Male             PhD  Software Engineer             8.090834
# 3  36.0    Male      Bachelor's    Sales Associate             7.000000
# 4  52.0    Male        Master's           Director             8.000000
#
#           Salary
# 0  115296.421831
# 1   65000.000000
# 2  150000.000000
# 3   60000.000000
# 4  200000.000000

# %%
# Create the DataFrame
data = {'Gender': ['Male', 'Female', 'Male', 'Female']}
df= pd.DataFrame(data)

# Replace 'male' with 1 and 'female' with 2 in the 'Sex' column
p1['Gender'] = p1['Gender'].replace({'Male': 0, 'Female': 1})

# Print the DataFrame to check
print(p1)
# Out:
#        Age Gender    Education Level              Job Title  \
# 0     32.0      0         Bachelor's      Software Engineer
# 1     28.0      1           Master's           Data Analyst
# 2     45.0      0                PhD      Software Engineer
# 3     36.0      0         Bachelor's        Sales Associate
# 4     52.0      0           Master's               Director
# ...    ...    ...                ...                    ...
# 6698  49.0      1                PhD  Director of Marketing
# 6699  32.0      0        High School        Sales Associate
# 6700  30.0      1  Bachelor's Degree      Financial Manager
# 6701  46.0      0    Master's Degree      Marketing Manager
# 6702  26.0      1        High School        Sales Executive
#
#       Years of Experience         Salary
# 0                5.000000  115296.421831
# 1                3.000000   65000.000000
# 2                8.090834  150000.000000
# 3                7.000000   60000.000000
# 4                8.000000  200000.000000
# ...                   ...            ...
# 6698            20.000000  200000.000000
# 6699             3.000000   50000.000000
# 6700             4.000000   55000.000000
# 6701            14.000000  140000.000000
# 6702             1.000000   35000.000000
#
# [6550 rows x 6 columns]

# %%
p1["Education Level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
import pandas as pd

# Sample DataFrame 'p1'
df = pd.DataFrame({'Education Level': ["Bachelor's", "Master's", "PhD", "High School"]})

# Modify values in 'Education Level' column for 'p1'
def standardize_education_level(edu_level):
    if edu_level.lower() in ["bachelor's", "bachelor's degree"]:
        return "Bachelor's"
    elif edu_level.lower() in ["master's", "master's degree"]:
        return "Master's"
    elif edu_level.lower() == "phd":
        return "PhD"
    else:
        return edu_level  # Return the original value if it doesn't match any of the specified categories

p1['Education Level'] = p1['Education Level'].apply(standardize_education_level)

print("Updated p1 DataFrame:")
print(p1)
# Out:
# Updated p1 DataFrame:
#        Age Gender Education Level              Job Title  Years of Experience  \
# 0     32.0      0      Bachelor's      Software Engineer             5.000000
# 1     28.0      1        Master's           Data Analyst             3.000000
# 2     45.0      0             PhD      Software Engineer             8.090834
# 3     36.0      0      Bachelor's        Sales Associate             7.000000
# 4     52.0      0        Master's               Director             8.000000
# ...    ...    ...             ...                    ...                  ...
# 6698  49.0      1             PhD  Director of Marketing            20.000000
# 6699  32.0      0     High School        Sales Associate             3.000000
# 6700  30.0      1      Bachelor's      Financial Manager             4.000000
# 6701  46.0      0        Master's      Marketing Manager            14.000000
# 6702  26.0      1     High School        Sales Executive             1.000000
#
#              Salary
# 0     115296.421831
# 1      65000.000000
# 2     150000.000000
# 3      60000.000000
# 4     200000.000000
# ...             ...
# 6698  200000.000000
# 6699   50000.000000
# 6700   55000.000000
# 6701  140000.000000
# 6702   35000.000000
#
# [6550 rows x 6 columns]

# %%
p1["Education Level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', 'High School'], dtype=object)

# %%
p1.head()
# Out:
#     Age Gender Education Level          Job Title  Years of Experience  \
# 0  32.0      0      Bachelor's  Software Engineer             5.000000
# 1  28.0      1        Master's       Data Analyst             3.000000
# 2  45.0      0             PhD  Software Engineer             8.090834
# 3  36.0      0      Bachelor's    Sales Associate             7.000000
# 4  52.0      0        Master's           Director             8.000000
#
#           Salary
# 0  115296.421831
# 1   65000.000000
# 2  150000.000000
# 3   60000.000000
# 4  200000.000000

# %%
import pandas as pd

# Sample DataFrame 'p1' with the 'Gender' column
df= pd.DataFrame({'Gender': ['Male', 'Female', 'Male', 'Female', 'Other' ]})

# Replace 'Male' with 0 and 'Female' with 1 in the 'Gender' column of 'p1'
p1['Gender'] = p1['Gender'].replace({'Male': 0, 'Female': 1,'Other': 2})

# Print the updated DataFrame to check
print(p1)
# Out:
#        Age  Gender Education Level              Job Title  \
# 0     32.0       0      Bachelor's      Software Engineer
# 1     28.0       1        Master's           Data Analyst
# 2     45.0       0             PhD      Software Engineer
# 3     36.0       0      Bachelor's        Sales Associate
# 4     52.0       0        Master's               Director
# ...    ...     ...             ...                    ...
# 6698  49.0       1             PhD  Director of Marketing
# 6699  32.0       0     High School        Sales Associate
# 6700  30.0       1      Bachelor's      Financial Manager
# 6701  46.0       0        Master's      Marketing Manager
# 6702  26.0       1     High School        Sales Executive
#
#       Years of Experience         Salary
# 0                5.000000  115296.421831
# 1                3.000000   65000.000000
# 2                8.090834  150000.000000
# 3                7.000000   60000.000000
# 4                8.000000  200000.000000
# ...                   ...            ...
# 6698            20.000000  200000.000000
# 6699             3.000000   50000.000000
# 6700             4.000000   55000.000000
# 6701            14.000000  140000.000000
# 6702             1.000000   35000.000000
#
# [6550 rows x 6 columns]

# %%
import pandas as pd

# Sample DataFrame 'p1' with the 'Educational Level' column
df = pd.DataFrame({'Education Level': ["Bachelor's", "Master's", "PhD", 'High School']})

# Replace educational levels with numerical values in the 'Educational Level' column of 'p1'
p1['Education Level'] = p1['Education Level'].replace({"Bachelor's": 0, "Master's": 1, "PhD": 2, 'High School': 3})

# Print the updated DataFrame to check
print(p1)
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0       0                0      Software Engineer
# 1     28.0       1                1           Data Analyst
# 2     45.0       0                2      Software Engineer
# 3     36.0       0                0        Sales Associate
# 4     52.0       0                1               Director
# ...    ...     ...              ...                    ...
# 6698  49.0       1                2  Director of Marketing
# 6699  32.0       0                3        Sales Associate
# 6700  30.0       1                0      Financial Manager
# 6701  46.0       0                1      Marketing Manager
# 6702  26.0       1                3        Sales Executive
#
#       Years of Experience         Salary
# 0                5.000000  115296.421831
# 1                3.000000   65000.000000
# 2                8.090834  150000.000000
# 3                7.000000   60000.000000
# 4                8.000000  200000.000000
# ...                   ...            ...
# 6698            20.000000  200000.000000
# 6699             3.000000   50000.000000
# 6700             4.000000   55000.000000
# 6701            14.000000  140000.000000
# 6702             1.000000   35000.000000
#
# [6550 rows x 6 columns]

# %%
p1.head()
# Out:
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0       0                0  Software Engineer             5.000000
# 1  28.0       1                1       Data Analyst             3.000000
# 2  45.0       0                2  Software Engineer             8.090834
# 3  36.0       0                0    Sales Associate             7.000000
# 4  52.0       0                1           Director             8.000000
#
#           Salary
# 0  115296.421831
# 1   65000.000000
# 2  150000.000000
# 3   60000.000000
# 4  200000.000000

# %% [markdown]
# ## Statistcal Analysis

# %% [markdown]
# \\ Null Hypothesis: Data is Normal

# %% [markdown]
# \\ Alternate Hypothesis: Data is not Normal

# %%
sns.histplot(p1["Years of Experience"], kde=1)
sns.histplot(p1["Age"], kde=1)
sns.histplot(p1["Salary"], kde=1)

# Perform Shapiro-Wilk test for normality
statistic, p = stats.shapiro(p1["Age"])

# Print the results
if p > 0.05:
    print(f'p-value: {p}. Sample looks Gaussian/Normally distributed (Could not Reject H0)')
else:
    print(f'p-value: {p}. Sample does not look Gaussian/Normally distributed (Reject H0)')

# Perform Shapiro-Wilk test for normality
statistic, p = stats.shapiro(p1["Years of Experience"])

# Print the results
if p > 0.05:
    print(f'p-value: {p}. Sample looks Gaussian/Normally distributed (Could not Reject H0)')
else:
    print(f'p-value: {p}. Sample does not look Gaussian/Normally distributed (Reject H0)')

# Perform Shapiro-Wilk test for normality
statistic, p = stats.shapiro(p1["Salary"])

# Print the results
if p > 0.05:
    print(f'p-value: {p}. Sample looks Gaussian/Normally distributed (Could not Reject H0)')
else:
    print(f'p-value: {p}. Sample does not look Gaussian/Normally distributed (Reject H0)')
p1.head()
# Out:
# p-value: 0.0. Sample does not look Gaussian/Normally distributed (Reject H0)
# p-value: 0.0. Sample does not look Gaussian/Normally distributed (Reject H0)
# p-value: 2.118531783552817e-38. Sample does not look Gaussian/Normally distributed (Reject H0)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0       0                0  Software Engineer             5.000000
# 1  28.0       1                1       Data Analyst             3.000000
# 2  45.0       0                2  Software Engineer             8.090834
# 3  36.0       0                0    Sales Associate             7.000000
# 4  52.0       0                1           Director             8.000000
#
#           Salary
# 0  115296.421831
# 1   65000.000000
# 2  150000.000000
# 3   60000.000000
# 4  200000.000000

# %% [markdown]
# # Transforming Data

# %%
p1.head()
# Out:
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0       0                0  Software Engineer             5.000000
# 1  28.0       1                1       Data Analyst             3.000000
# 2  45.0       0                2  Software Engineer             8.090834
# 3  36.0       0                0    Sales Associate             7.000000
# 4  52.0       0                1           Director             8.000000
#
#           Salary
# 0  115296.421831
# 1   65000.000000
# 2  150000.000000
# 3   60000.000000
# 4  200000.000000

# %%
#LOG TRANSFORM
p1["Age"] = np.log(p1["Age"])
p1["Years of Experience"] = np.log(p1["Years of Experience"])
p1["Salary"] = np.log(p1["Salary"])


#p1.head()
print(stats.shapiro(p1["Age"]))
print(stats.shapiro(p1["Years of Experience"]))
print(stats.shapiro(p1["Salary"]))

sns.histplot(p1["Age"], kde=1)
sns.histplot(p1["Years of Experience"], kde=1)
sns.histplot(p1["Salary"], kde=1)
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.9653039574623108, pvalue=5.457142302492143e-37)
# ShapiroResult(statistic=nan, pvalue=1.0)
# ShapiroResult(statistic=0.9158235192298889, pvalue=0.0)
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## Levene Test

# %% [markdown]
# \\ Null Hypothesis: Data is Homoginous

# %% [markdown]
# \\ Alternate Hypothesis: Data is not Homoginous

# %%
import scipy.stats as stats
import pandas as pd

# Assuming you have already loaded your data into the p1 DataFrame

# Extract 'Age' and 'Fare' columns from the p1 DataFrame
age_column = p1['Age']
experience_column = p1['Years of Experience']
salary_column = p1['Salary']



# Perform Levene Test
w_stat, p_val = stats.levene(age_column, experience_column, salary_column)

print("w_statistic:", w_stat)
print("p-value:", p_val)

if p_val < 0.05:  # Assuming alpha level of 0.05
    print(f"Variances are equal: Fail to Reject the null hypothesis")
else:
    print(f"Variances are not equal: Reject the null hypothesis")
# Out:
# w_statistic: nan
# p-value: nan
# Variances are not equal: Reject the null hypothesis
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:3180: RuntimeWarning: invalid value encountered in subtract
#   numer = (Ntot - k) * np.sum(Ni * (Zbari - Zbar)**2, axis=0)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:3185: RuntimeWarning: invalid value encountered in subtract
#   dvar += np.sum((Zij[i] - Zbari[i])**2, axis=0)

# %% [markdown]
# ## Chi-Squared Test

# %%
contigency_table = pd.crosstab(p1["Gender"], p1["Education Level"])
contigency_table
# Out:
# Education Level     0     1    2    3
# Gender
# 0                1815   774  789  185
# 1                1198  1063  467  251
# 2                   0     2    0    6

# %%
chi2, p, dof, expected = stats.chi2_contingency(contigency_table)

# Print
print("Chi_Square Statistic:", chi2)
print("p-value:", p)
print("Degrees of Freedom:", dof)
print("Expected:", expected)
# Out:
# Chi_Square Statistic: 274.2614828051794
# p-value: 2.657352456451273e-56
# Degrees of Freedom: 6
# Expected: [[1.63898000e+03 1.00035985e+03 6.83225649e+02 2.40434504e+02]
#  [1.37034000e+03 8.36394046e+02 5.71240305e+02 2.01025649e+02]
#  [3.68000000e+00 2.24610687e+00 1.53404580e+00 5.39847328e-01]]

# %% [markdown]
# ## Wilcoxon(Paired Sampling)

# %%
from scipy.stats import wilcoxon

# Extract the columns from the p1 DataFrame
age_column = p1['Age']
experience_column = p1['Years of Experience']
salary_column = p1['Salary']

# Perform Wilcoxon signed-rank test between 'Age' and 'Years of Experience'
statistic_1, p_val_1 = wilcoxon(age_column, experience_column)
print("Test statistic between Age and Years of Experience:", statistic_1)
print("p-value between Age and Years of Experience:", p_val_1)

# Perform Wilcoxon signed-rank test between 'Age' and 'Salary'
statistic_2, p_val_2 = wilcoxon(age_column, salary_column)
print("\nTest statistic between Age and Salary:", statistic_2)
print("p-value between Age and Salary:", p_val_2)

# Perform Wilcoxon signed-rank test between 'Years of Experience' and 'Salary'
statistic_3, p_val_3 = wilcoxon(experience_column, salary_column)
print("\nTest statistic between Years of Experience and Salary:", statistic_3)
print("p-value between Years of Experience and Salary:", p_val_3)

alpha = 0.05  # Significance level

if any(p_val < alpha for p_val in [p_val_1, p_val_2, p_val_3]):
    print("\nThere is a significant difference between at least one pair of the Age, Years of Experience, and Salary columns.")
else:
    print("\nThere is no significant difference between any pair of the Age, Years of Experience, and Salary columns.")
# Out:
# Test statistic between Age and Years of Experience: 0.0
# p-value between Age and Years of Experience: 0.0
#
# Test statistic between Age and Salary: 0.0
# p-value between Age and Salary: 0.0
#
# Test statistic between Years of Experience and Salary: 0.0
# p-value between Years of Experience and Salary: 0.0
#
# There is a significant difference between at least one pair of the Age, Years of Experience, and Salary columns.

# %% [markdown]
# ## Spearman's Correlation Coefficient

# %%
def pearson(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    x_std = np.std(x)
    y_std = np.std(y)
    n = len(x)
    return sum((x-x_mean)*(y-y_mean))/(n*x_std*y_std)

def spearman(x,y):
    x_rank = pd.Series(x).rank()
    y_rank = pd.Series(y).rank()
    return pearson(x_rank,y_rank)

# Example Dataset
x=(p1["Age"])
y=(p1["Years of Experience"])

print(f"Spearman Correlation Coefficient: {spearman(x,y)}")
# Differentiate all values
if spearman(x,y) < 0.6 > 0:
    print("Positive Relation")
elif spearman(x,y) > 0.6:
    print("Highly Positive Relation")
elif spearman(x,y) > -0.6 < 0:
    print("Negative Correlation")
elif  spearman(x,y) < -0.6:
    print("Highly Negative Correlation")
else:
    print("No Relation")
# Out:
# Spearman Correlation Coefficient: 0.941199227668826
# Highly Positive Relation

# %%
data =pd.DataFrame({'Age': x, 'Years of Experience': y})
heatmap_data = data.corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap between Age and Years of Experience')
plt.show()

# %%
def pearson(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    x_std = np.std(x)
    y_std = np.std(y)
    n = len(x)
    return sum((x-x_mean)*(y-y_mean))/(n*x_std*y_std)

def spearman(x,y):
    x_rank = pd.Series(x).rank()
    y_rank = pd.Series(y).rank()
    return pearson(x_rank,y_rank)

# Example Dataset
x=(p1["Age"])
y=(p1["Salary"])

print(f"Spearman Correlation Coefficient: {spearman(x,y)}")
# Differentiate all values
if spearman(x,y) < 0.6 > 0:
    print("Positive Relation")
elif spearman(x,y) > 0.6:
    print("Highly Positive Relation")
elif spearman(x,y) > -0.6 < 0:
    print("Negative Correlation")
elif  spearman(x,y) < -0.6:
    print("Highly Negative Correlation")
else:
    print("No Relation")
# Out:
# Spearman Correlation Coefficient: 0.7311259558132425
# Highly Positive Relation

# %%
data =pd.DataFrame({'Age': x, 'Salary': y})
heatmap_data = data.corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap between Age and Salary')
plt.show()

# %%
def pearson(x, y):
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    x_std = np.std(x)
    y_std = np.std(y)
    n = len(x)
    return sum((x-x_mean)*(y-y_mean))/(n*x_std*y_std)

def spearman(x,y):
    x_rank = pd.Series(x).rank()
    y_rank = pd.Series(y).rank()
    return pearson(x_rank,y_rank)

# Example Dataset
x=(p1["Years of Experience"])
y=(p1["Salary"])

print(f"Spearman Correlation Coefficient: {spearman(x,y)}")
# Differentiate all values
if spearman(x,y) < 0.6 > 0:
    print("Positive Relation")
elif spearman(x,y) > 0.6:
    print("Highly Positive Relation")
elif spearman(x,y) > -0.6 < 0:
    print("Negative Correlation")
elif  spearman(x,y) < -0.6:
    print("Highly Negative Correlation")
else:
    print("No Relation")
# Out:
# Spearman Correlation Coefficient: 0.8512746456749831
# Highly Positive Relation

# %%
data =pd.DataFrame({'Years of Experience ': x, 'Salary': y})
heatmap_data = data.corr(method='spearman')

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap between Years of Experience and Salary')
plt.show()

# %% [markdown]
# # Organize Data

# %%
p1.columns
# there's no need to change Column name or make any new
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %% [markdown]
# ## Swarmplot

# %%
sns.swarmplot(data=p1, x="Gender", y="Age",hue="Education Level")
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 79.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 75.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='Age'>
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 84.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 81.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=p1, x="Gender", y="Salary",hue="Education Level")
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 86.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='Salary'>
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 91.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=p1, x="Gender", y="Years of Experience",hue="Education Level")
# Out:
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 86.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 83.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='Years of Experience'>
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 89.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\osman\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 87.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
table = pd.pivot_table(p1, values="Years of Experience", index="Job Title", columns = "Education Level", aggfunc=np.sum )
table
# Out:
# C:\Users\osman\AppData\Local\Temp\ipykernel_15108\3111328764.py:1: FutureWarning: The provided callable <function sum at 0x000001D9D8EA2DE0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table = pd.pivot_table(p1, values="Years of Experience", index="Job Title", columns = "Education Level", aggfunc=np.sum )
# Education Level                    0          1   2         3
# Job Title
# Account Manager             1.609438        NaN NaN       NaN
# Accountant                  2.995732        NaN NaN       NaN
# Administrative Assistant    4.382027        NaN NaN       NaN
# Back end Developer        223.445205       -inf NaN      -inf
# Business Analyst            1.945910   1.609438 NaN       NaN
# ...                              ...        ...  ..       ...
# UX Designer                      NaN   1.609438 NaN       NaN
# UX Researcher                    NaN   0.693147 NaN       NaN
# VP of Finance                    NaN   2.944439 NaN       NaN
# VP of Operations                 NaN   1.609438 NaN       NaN
# Web Developer              59.079958  55.010163 NaN  1.386294
#
# [193 rows x 4 columns]

# %%
sns.pairplot(p1)

# %%
p1.to_csv("Wrangled Data of Salary_Dataset.csv")
